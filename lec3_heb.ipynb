# %%
# %%html
# <!-- RTL Fix the jupyter notebook 7  -->
# <style>
#     .jp-RenderedHTMLCommon {
#         padding-top: 2em !important;
#   }
#     .jp-RenderedHTMLCommon, .jp-RenderedHTMLCommon * {
#         direction: rtl !important;
#         text-align:right !important;
#   }
#     .jp-MarkdownCell .jp-InputArea-editor {
#         direction: rtl !important;
#         text-align:right !important;
#         padding-top: 2em !important;
#   }
#
#  .jp-RenderedHTMLCommon code, .jp-RenderedHTMLCommon code span {
#         text-align:left !important;
#         direction: ltr !important;
#         unicode-bidi: embed !important;
#
#     }
#     .jp-RenderedHTMLCommon pre:has(code) {
#       direction: ltr !important;
#       text-align: left!important;
#     }
#
# </style>
# Out:
# <!-- RTL Fix the jupyter notebook 7  -->
# <style>
#     .jp-RenderedHTMLCommon {
#         padding-top: 2em !important;
#   }
#     .jp-RenderedHTMLCommon, .jp-RenderedHTMLCommon * {
#         direction: rtl !important;
#         text-align:right !important;
#   }
#     .jp-MarkdownCell .jp-InputArea-editor {
#         direction: rtl !important;
#         text-align:right !important;
#         padding-top: 2em !important;
#   }
#
#  .jp-RenderedHTMLCommon code, .jp-RenderedHTMLCommon code span {
#         text-align:left !important;
#         direction: ltr !important;
#         unicode-bidi: embed !important;
#
#     }
#     .jp-RenderedHTMLCommon pre:has(code) {
#       direction: ltr !important;
#       text-align: left!important;
#     }
#
# </style>

# %%
# %%html
# <script>
# (function() {
#   // Create the toggle button
#   const rtlButton = document.createElement("button");
#   rtlButton.textContent = "Toggle LTR";
#   rtlButton.id = "top-rtl-toggle";
#   rtlButton.style.marginLeft = "8px";
#   rtlButton.style.padding = "4px 10px";
#   rtlButton.style.fontSize = "14px";
#   rtlButton.style.cursor = "pointer";
#
#   // State
#   var rtlActive = false;
#
#   // Styling function
#   var applyStyleToEditor = (editor) => {
#     if (!editor) return;
#     var direction = getComputedStyle(editor).getPropertyValue('direction')=='rtl' ? 'ltr' : 'rtl';
#     var text_align = getComputedStyle(editor).getPropertyValue('text-align')=='right' ? 'left' : 'right';
#     editor.style.setProperty('direction', direction, 'important');
#     editor.style.setProperty('text-align', text_align, 'important');
#   };
#
#   // Toggle logic
#   rtlButton.onclick = () => {
#     rtlActive = !rtlActive;
#     rtlButton.textContent = rtlActive ? "Toggle LTR" : "Toggle RTL";
#     document.querySelectorAll('.jp-MarkdownCell .jp-InputArea-editor').forEach(applyStyleToEditor);
#     document.querySelectorAll('.jp-RenderedHTMLCommon code, .jp-RenderedHTMLCommon code span').forEach(applyStyleToEditor);
#     document.querySelectorAll('jp-RenderedHTMLCommon, .jp-RenderedHTMLCommon *').forEach(applyStyleToEditor);
#   };
#
#   // Watch for focus into editing Markdown cells
#   // document.addEventListener('focusin', (event) => {
#   //   const editor = event.target.closest('.jp-MarkdownCell .jp-InputArea-editor');
#   //    if (editor) applyStyleToEditor(editor);
#   // });
#
#   // Insert into top toolbar if not already present
#   var insertIntoToolbar = () => {
#     const toolbar = document.querySelector('.jp-NotebookPanel-toolbar');
#     if (toolbar && !document.getElementById("top-rtl-toggle")) {
#       toolbar.appendChild(rtlButton);
#     } else {
#       // Try again in a moment if toolbar isn't ready yet
#       setTimeout(insertIntoToolbar, 300);
#     }
#   };
#
#   insertIntoToolbar();
# })();
# </script>
# Out:
# <script>
# (function() {
#   // Create the toggle button
#   const rtlButton = document.createElement("button");
#   rtlButton.textContent = "Toggle LTR";
#   rtlButton.id = "top-rtl-toggle";
#   rtlButton.style.marginLeft = "8px";
#   rtlButton.style.padding = "4px 10px";
#   rtlButton.style.fontSize = "14px";
#   rtlButton.style.cursor = "pointer";
#
#   // State
#   var rtlActive = false;
#
#   // Styling function
#   var applyStyleToEditor = (editor) => {
#     if (!editor) return;
#     var direction = getComputedStyle(editor).getPropertyValue('direction')=='rtl' ? 'ltr' : 'rtl';
#     var text_align = getComputedStyle(editor).getPropertyValue('text-align')=='right' ? 'left' : 'right';
#     editor.style.setProperty('direction', direction, 'important');
#     editor.style.setProperty('text-align', text_align, 'important');
#   };
#
#   // Toggle logic
#   rtlButton.onclick = () => {
#     rtlActive = !rtlActive;
# ...

# %% [markdown]
# # המשך רשימות ופונקציות, ומילונים

# %% [markdown]
# ## עיקרי השיעור הקודם

# %% [markdown]
# - רשימות:
# ```python
# [1, 2, 3, ..]
# ["a", 0, 1.37]
# ```
#
# - טווחים (Ranges):
# ```python
# range(7)
# range(1, 10, 2)
# ```
#
# - לולאות:
# ```python
# while condition:
#     statement1
#     ...
# for a in range(x):
#     statement1
#     ...
# for a in [param1, ..]:
#     statement1
#     ...
# ```

# %% [markdown]
# ## נושאים להיום
#
# - המשך השמות (assignments)
#     - הפניות
#     - <span style="color:green"> משתנים ניתנים לשינוי </span> לעומת <span style="color:red"> משתנים קבועים </span>
#
# - המשך פונקציות
#     - תחום תוקף (scope)
#     - <span style="color:green"> משתנים גלובליים </span> לעומת <span style="color:blue"> מקומיים </span>
#     - פרמטרים עם ערכי ברירת מחדל
#     - פונקציות למבדה
#
# - מבני נתונים חדשים
#     - tuples
#     - מילונים
#
# - המשך רשימות
#     - List Comprehension

# %% [markdown]
# # השמות (חלק 2)
#
# - כל המידע בפייתון מאוחסן באובייקטים מטיפוסים שונים (אין טיפוסים פרימיטיביים).
# - `a=3` יוצר גם אובייקט חדש (3) וגם שם שמצביע עליו.
# - השמה של משתנה לאחר (`b=a`) מעתיקה את ההפניה (הכתובת בזיכרון) ולא את הערך עצמו.
#
#
#
# <img width=800 height=350 src='data:image/png;base64,...'>

# %% [markdown]
# ### השמה של רשימות

# %%
orig_list = [1,2,3]
copy_list = orig_list 
orig_list = [6,7,8,9]

# %%
print(copy_list)
print(orig_list)

# %% [markdown]
# No suprises so far...

# %%
orig_list = [6,7,8,9]
copy_list = orig_list 
orig_list[0] = 1000

# %%
print(orig_list)
print(copy_list)

# %% [markdown]
# #### ההפניה עדיין קיימת!

# %% [markdown]
# ## משתנים ניתנים לשינוי (mutable) לעומת קבועים (immutable)

# %% [markdown]
# - אובייקטים ניתנים לשינוי אפשר לערוך לאחר יצירה.

# %% [markdown]
# - אובייקטים הניתנים לשינוי אפשר לערוך לאחר יצירה.

# %%
my_list = [1, 2, 4, 5, 7, 8]
my_list[4] = 500

# %% [markdown]
# - מחרוזות (strings) הן קבועות:

# %%
my_string = 'aaa'
my_string[2] = 'b'

# %% [markdown]
# - גם `int`, `float`, `bool` הם קבועים:

# %%
a=5
b=a
a+=1

# %% [markdown]
# המשתנה `a` מפנה כעת לאובייקט אחר

# %% [markdown]
# ## דוגמה להשמה עם משתנים קבועים

# %%
a=1
b=2
c=a

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <img width=600 heigth=300 src='data:image/png;base64,...' />

# %% [markdown]
# <img width=500 heigth=300 src='data:image/png;base64,...' />

# %% [markdown]
# - `a`, `b`, `c` הם שמות שמצביעים לאובייקטים בזיכרון.
# - `a=1` יוצר גם משתנה וגם אובייקט.
# - בדקו זאת בעצמכם באתר [Python Tutor](http://www.pythontutor.com/)

# %% [markdown]
# ## דוגמה עם משתנים ניתנים לשינוי

# %%
L1=[1,2,3]
L2=L1

# %% [markdown]
# <img width=600 height=600 src='data:image/png;base64,...' />

# %% [markdown]
# בדקו זאת ב [Python Tutor](http://www.pythontutor.com/)

# %% [markdown]
# # פונקציות (חלק 2):

# %% [markdown]
# ### משתנים אקטואריים ופורמליים

# %% [markdown]
# הגדרת פונקציה כוללת את רשימת הפרמטרים שלה, כפי שראינו. למשל בפונקציה max2 קבענו שלפונקציה שני פרמטרים, ונתנו להם את השמות a ו- b. הפרמטרים האלו נקראים פרמטרים פורמליים, כי הם משמשים להגדרה של הפונקציה. בשלב הגדרת הפונקציה אין לפרמטרים האלו ערכים ספציפיים. ערכים ספציפיים יינתנו בעת הקריאה לפונקציה מאוחר יותר.
#
# בכל פעם שקוראים לפונקציה מעבירים לה ערכים ספציפיים. ערכים אלו נקראים פרמטרים אקטואליים. למשל, בעת הקריאה:
# ```python
# max2(5,7)
# ```
# הפרמטרים האקטואליים הם 5 ו- 7.
# מה שקורה בעצם בעת קריאה לפונקציה הוא זה: הפרמטרים האקטואליים מוצבים לתוך הפרמטרים הפורמליים לפי הסדר. בדוגמה הנ"ל, 5 מוצב לתוך a ו- 7 לתוך b. לאחר הצבה זו, הפונקציה יכולה להתחיל לפעול כפי שהוסבר קודם.
#
# ניראה עוד דוגמה:
# ```python
# def what(st, c):
#     if c in st:
#         return True
#     else:
#         return False
#
# print(what("hello", "t"))
# print(what("hello", "e"))
# ```
# הפונקציה בודקת האם תו כלשהו c מופיע בתוך מחרוזת st. שני אלו – st ו- c הם פרמטרים פורמליים. בעת קריאה לפונקציה, למשל what(“hello”, “t”) מועברים לה פרמטרים אקטואליים – “hello” ו- “t”. הערך האקטואלי “hello” מוצב לתוך הפרמטר הפורמלי st, ואילו “t” מוצב לתוך c. וכעת הפונקציה מתחילה לעבוד.

# %% [markdown]
# שימו לב שאין שום בעיה שיוגדרו פרמטרים אקטואליים עם שמות זהים לאלו של הפרמטרים הפורמליים. למשל:
# ```python
# st = “blabla”
# c = “a”
# what(st, c)
# ```
# המשתנים st ו- c שהוגדרו לפני הקריאה לפונקציה הם פרמטרים אקטואליים! ערכיהם מוצבים לתוך פרמטרים פורמליים עם אותם שמות, אבל אין מעבר לכך שום קשר בין המשתנים ה"חיצוניים" למשתנים שבתוך הפונקציה. עדות לכך ניתן לקבל בתרגיל הבא.
#
# הנה פונקציה שמשנה את הפרמטר הפורמלי שלה (מקבלת מספר n, מגדילה אותו ב- 1 ומחזירה את הערך החדש):
# ```python
# def add1(n):
#     n = n + 1
#     return n
# ```
# בחלונית שלפניכם הקוד לפונקציה שהוצגה זה עתה. הריצו את הפונקציה עם המספר 6 כקלט והדפיסו את התוצאה. מה מחזירה הפונקציה?

# %%
def add1(n):
    n = n + 1
    return n

# %% [markdown]
# כעת הגדירו משתנה בשם n, והציבו לתוכו את הערך 6:
# ```python
# n = 6
# ```
# קראו לפונקציה add1 עם n שהגדרתם כקלט, הדפיסו את הערך אותו החזירה הפונקציה ולאחר מכן הדפיסו את ערכו של n.
#
# מה מחזירה הפונקציה?
# מה ערכו של n שהוגדר מחוץ לפונקציה (ה"אקטואלי") לאחר סיום ריצת הפונקציה?
#
# ראינו שהמשתנה n שהוגדר מחוץ לפונקציה לא השתנה בעקבות פעולת הפונקציה. מה שלמדנו כאן הוא זה: גם כאשר לפרמטר אקטואלי יש אותו שם כמו פרמטר פורמלי, אין ביניהם שום קשר, מלבד ההצבה בזמן הקריאה לפונקציה. מדובר בשני משתנים שונים. אנחנו אומרים שהמשתנים הללו, למרות שמם הזהה, נמצאים בסביבות (scopes) שונות – הסביבה החיצונית והסביבה הפנימית של הפונקציה.
#
# הסתכלו כעת על הדוגמה הבאה:
# ```python
# n = 6
# m = add1(n)
# ```
# מה ערכו של m?
# ומה לגבי המקרה הבא?
# ```python
# n = 6
# n = add1(n)
# ```
# הפעם, הערך שמחזירה הפונקציה (7) נשמר בתוך המשתנה n! לכן ערכו כן ישתנה לערך שהחזירה הפונקציה. אבל אין לכך שום קשר לשמות הזהים של המשתנים.

# %% [markdown]
# #### scope
#
# טווח (Scope) מתייחס לאילו חלקים בתוכנית שלך יכולים לראות או להשתמש במשתנה
#
# - כאשר מריצים פונקציה, נוצר עבורה scope חדש:
# הפרמטרים המוגדרים הם מקומיים (local)
# - הם מוגדרים בתוך הטווח ואז "נעלמים"
# - השורה שקוראת לפונקציה "רואה" רק את התוצאות
#
# <img src='data:image/png;base64,...'>

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/YKBTuyCLuPo?si=7GYEZtkwq278KDx_" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/YKBTuyCLuPo?si=7GYEZtkwq278KDx_" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# **לנוחיותכם חלונית עם הקוד שראינו בסרטון בpython tutor. מוזמנים להריץ בעצמכם:**

# %%
# %%html
# <iframe width="1000" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=def%20max3_v1%28a,b,c%29%3A%0A%20%20%20%20if%20a%20%3E%20b%3A%0A%20%20%20%20%20%20%20%20if%20a%20%3E%20c%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20a%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20c%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20if%20b%20%3E%20c%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20b%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20c%0A%0Aa%20%3D%201%0Ab%20%3D%202%0Ac%20%3D%203%0Aresult%20%3D%20max3_v1%28a,b,c%29&amp;codeDivHeight=400&amp;codeDivWidth=350&amp;cumulative=false&amp;curInstr=0&amp;heapPrimitives=nevernest&amp;origin=opt-frontend.js&amp;py=3&amp;rawInputLstJSON=%5B%5D&amp;textReferences=false"> </iframe>
# Out:
# <iframe width="800" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=def%20max3_v1%28a,b,c%29%3A%0A%20%20%20%20if%20a%20%3E%20b%3A%0A%20%20%20%20%20%20%20%20if%20a%20%3E%20c%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20a%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20c%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20if%20b%20%3E%20c%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20b%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20c%0A%0Aa%20%3D%201%0Ab%20%3D%202%0Ac%20%3D%203%0Aresult%20%3D%20max3_v1%28a,b,c%29&amp;codeDivHeight=400&amp;codeDivWidth=350&amp;cumulative=false&amp;curInstr=0&amp;heapPrimitives=nevernest&amp;origin=opt-frontend.js&amp;py=3&amp;rawInputLstJSON=%5B%5D&amp;textReferences=false"> </iframe>

# %% [markdown]
# <h4 style="color:purple">
# בחנו את עצמכם
# </h4>

# %% [markdown]
# בדוגמה שלפניכם קטע קוד קצר בו מוגדרת פונקציה וקריאה לה:
# ```python
# def what(string, char):
# 	if char*3 in string:
# 		return True
# 	else:
# 		return False
#
# letter = "a"
# text = "hello aaa world"
#
# print(what(text, letter))
# ```
# לכל פרמטר בתוכנית קבעו האם הוא פרמטר פורמלי או אקטואלי וגררו אותו אל התיבה המתאימה.

# %%
import json
from jupyterquiz import display_quiz
example = \
'''
   [{
    
        "question": "סמנו את הפרמטרים האקטואריים",
        "type": "many_choice",
        "answers": [
            {
                "answer": "letter",
                "correct": true,
                "feedback": "נכון!"
            },
            {
                "answer": "char",
                "correct": false,
                "feedback": "לא נכון"
            },
            {
                "answer": "string",
                "correct": false,
                "feedback": "לא נכון"

            },
            {
                "answer": "text",
                "correct": true,
                "feedback": "נכון!"

            }
        ]
    }]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="HbetIKgzbOmS" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #HbetIKgzbOmS {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# התבוננו בקטע הקוד הבא וענו על השאלות שאחריו:
# ```python
# def foo(a,b):
#   print(a, b)
#   a = 123
#   b = 456
#   print(a,b)
#   foo(b,a)
# ```
# **שימו לב**, כי הפונקציה foo לא מחזירה דבר, אלא רק מדפיסה. בשאלה זו נתעניין **בתוצאת ההדפסה** בלבד.

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה מודפס לאחר שמפעילים את שורה 6?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "123 456",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "123",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "456 123",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "456",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="VOasGFlnbsov" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #VOasGFlnbsov {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה מודפס לאחר שמפעילים שורה 7 (מתעלמים מההדפסה שבשורה 6)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "123 456",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "123",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "456 123",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "456",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="EcgvHlTEBWlW" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #EcgvHlTEBWlW {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ## משתנים מקומיים וגלובליים

# %% [markdown]
# - משתנה **מקומי** מוגדר בפונקציה, קיים רק בתוכה.
# - משתנה **גלובלי** מוגדר מחוץ לפונקציה וזמין גם בתוכה.

# %%
def myFunc():
    localVar = 5
    print(localVar)
    print(globalVar)

# %%
globalVar = 10
myFunc()
print(globalVar + 1)

# %%
print(localVar) # Error

# %% [markdown]
# ### העברת (וקבלת) מידע לפונקציות (ומפונקציות)

# %% [markdown]
# - האם פונקציות יכולות לשנות אובייקטים שהן מקבלות כפרמטרים?
#     - **לא יכולות** לשנות אובייקטים בלתי-ניתנים לשינוי (immutable) שנשלחו אליהן (כמו מספרים או מחרוזות).
#     - **כן יכולות** לשנות אובייקטים ניתנים לשינוי (mutable) שנשלחו אליהן (כמו רשימות).
#         - שינויים שנעשו באובייקטים האלה יישמרו גם לאחר סיום הפונקציה.

# %%
def func(x):
    x.append(9)
    
a=[4,5,6,7,8]
print(a)
func(a)
print(a)

# %% [markdown]
# <img width=400, height=200, src="data:image/png;base64,...">

# %% [markdown]
# ## סיכום: כיצד להחזיר ערכים מפונקציה?

# %% [markdown]
# - שימוש ב-`return`
# - שינוי משתנים ניתנים לשינוי
# - <span style="color:gray">שימוש במשתנים גלובליים (לא בחומר)</span>

# %% [markdown]
# ### פונקציות שקוראות לפונקציות

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/UGBGnHOl6UQ?si=HzLggu2dJaRLKogY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/UGBGnHOl6UQ?si=HzLggu2dJaRLKogY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# <h4 style="color:purple">
# בחנו את עצמכם
# </h4>

# %% [markdown]
# מה מהמשפטים הבאים נכון לגבי המימוש של הפונקציה max10 שראינו זה עתה?

# %% [markdown]
# <img width=400 height=300 src="data:image/png;base64,..." />

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה מהמשפטים הבאים נכון לגבי השימוש של הפונקציה max10 שראינו זה עתה?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפונקציה max3 מוגדרת 4 פעמים ונקראת פעם אחת.",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "הפונקציה max3 מוגדרת פעם אחת ונקראת 4 פעמים.",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "הפונקציה max3 מוגדרת פעם אחת ונקראת פעם אחת.",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "הפונקציה max3 מוגדרת 4 פעמים ונקראת 4 פעמים.",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="UZDuFBtOqtjc" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #UZDuFBtOqtjc {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
# %%html
# <iframe width="1000" height="500" src="https://www.youtube.com/embed/Fg1tIcqTPg8?si=ItvmpJcINB0RrmME" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# **לנוחותכם חלונית עם הקוד שראינו בסרטון בpython tutor. מוזמנים להריץ בעצמכם:**

# %%
# %%html
# <iframe width="1000" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=def%20max2%28a,%20b%29%3A%0A%20%20%20%20if%20a%20%3E%20b%3A%0A%20%20%20%20%20%20%20%20return%20a%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20b%0A%0Adef%20max3_v3%28a,b,c%29%3A%0A%20%20%20%20max_a_b%20%3D%20max2%28a,b%29%0A%20%20%20%20max_all%20%3D%20max2%28max_a_b,%20c%29%0A%20%20%20%20return%20max_all%0A%0Aresult%20%3D%20max3_v3%281,2,3%29&amp;codeDivHeight=400&amp;codeDivWidth=350&amp;cumulative=false&amp;curInstr=0&amp;heapPrimitives=nevernest&amp;origin=opt-frontend.js&amp;py=3&amp;rawInputLstJSON=%5B%5D&amp;textReferences=false"> </iframe>

# %% [markdown]
# <h4 style="color:purple">
# בחנו את עצמכם
# </h4>

# %% [markdown]
# התבוננו בקטע הקוד הבא:
#
# ```python
# def max2(a, b):
# 		if a > b:
# 			return a
# 		else:
# 			return b
#
# 	def max3(a, b, c):
# 		max_a_b = max2(a, b)
# 		max_all = max2(max_a_b, c)
# 		return max_all
#
# 	def max4_v1(a, b, c, d):
# 		max_a_b_c = max3(a, b, c)
# 		max_all = max2(max_a_b_c, d)
# 		return max_all
#
#
# 	max4_v1(7,13,0,42)
# ```

# %% [markdown]
# בקטע זה מופיעות הפונקציות max2 ו-max3 אותן כבר ראינו. בנוסף, מוצגת הפונקציה max4_v1 המקבלת כקלט 4 מספרים ומחזירה את הגדול מביניהם. הפונקציה עובדת על פי דיאגרמת הבלוקים הבאה:

# %% [markdown]
# <img width=400 height=400 src='data:image/png;base64,...' />

# %% [markdown]
# שימו לב כי בשורה האחרונה בקוד מבוצעת קריאה לפונקציה הזו.
#
# ענו על השאלות הבאות על פי קטע הקוד הנ"ל.

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מהו ערכו של המשתנה max_all בפונקציה max4_v1? שימו לב כי זהו גם ערך ההחזרה של הפונקציה.",
    "type": "many_choice",
    "answers": [
        {
            "answer": "0",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "13",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "42",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "7",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="mzJWAaqFyRnA" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #mzJWAaqFyRnA {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "בשורה 13 מתבצעת קריאה לפונקציה max3. מהו ערכו של המשתנה max_a_b המופיע בפונקציה max3 (שורה 8)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "0",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "42",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "13",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "7",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="EGMrqkQDHdOM" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #EGMrqkQDHdOM {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/SB4bjVPDfZM?si=-Tbtl9lWKDOwixCE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/SB4bjVPDfZM?si=-Tbtl9lWKDOwixCE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# **לנוחיותכם חלונית עם הקוד שראינו בסרטון בpython tutor. מוזמנים להריץ בעצמכם:**

# %%
# %%html
# <iframe width="1000" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=def%20max2%28a,%20b%29%3A%0A%20%20%20%20if%20a%20%3E%20b%3A%0A%20%20%20%20%20%20%20%20return%20a%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20b%0A%0Adef%20max3_v3%28a,b,c%29%3A%0A%20%20%20%20max_a_b%20%3D%20max2%28a,b%29%0A%20%20%20%20max_all%20%3D%20max2%28max_a_b,%20c%29%0A%20%20%20%20return%20max_all%0A%0Adef%20max10%28a1,%20a2,%20a3,%20a4,%20a5,%20a6,%20a7,%20a8,%20a9,%20a10%29%3A%0A%20%20%20%20x%20%3D%20max3_v3%28a1,%20a2,%20a3%29%0A%20%20%20%20y%20%3D%20max3_v3%28a4,%20a5,%20a6%29%0A%20%20%20%20z%20%3D%20max3_v3%28a7,%20a8,%20a9%29%0A%20%20%20%20max_xyz%20%3D%20max3_v3%28x,%20y,%20z%29%0A%20%20%20%20result%20%3D%20max2%28max_xyz,%20a10%29%0A%20%20%20%20return%20result%0A%0Ares%20%3D%20max10%281,%202,%203,%204,%205,%206,%207,%208,%209,%2010%29&amp;codeDivHeight=400&amp;codeDivWidth=350&amp;cumulative=false&amp;curInstr=0&amp;heapPrimitives=nevernest&amp;origin=opt-frontend.js&amp;py=3&amp;rawInputLstJSON=%5B%5D&amp;textReferences=false"> </iframe>
# Out:
# <iframe width="1000" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=def%20max2%28a,%20b%29%3A%0A%20%20%20%20if%20a%20%3E%20b%3A%0A%20%20%20%20%20%20%20%20return%20a%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20b%0A%0Adef%20max3_v3%28a,b,c%29%3A%0A%20%20%20%20max_a_b%20%3D%20max2%28a,b%29%0A%20%20%20%20max_all%20%3D%20max2%28max_a_b,%20c%29%0A%20%20%20%20return%20max_all%0A%0Adef%20max10%28a1,%20a2,%20a3,%20a4,%20a5,%20a6,%20a7,%20a8,%20a9,%20a10%29%3A%0A%20%20%20%20x%20%3D%20max3_v3%28a1,%20a2,%20a3%29%0A%20%20%20%20y%20%3D%20max3_v3%28a4,%20a5,%20a6%29%0A%20%20%20%20z%20%3D%20max3_v3%28a7,%20a8,%20a9%29%0A%20%20%20%20max_xyz%20%3D%20max3_v3%28x,%20y,%20z%29%0A%20%20%20%20result%20%3D%20max2%28max_xyz,%20a10%29%0A%20%20%20%20return%20result%0A%0Ares%20%3D%20max10%281,%202,%203,%204,%205,%206,%207,%208,%209,%2010%29&amp;codeDivHeight=400&amp;codeDivWidth=350&amp;cumulative=false&amp;curInstr=0&amp;heapPrimitives=nevernest&amp;origin=opt-fr
# ...

# %% [markdown]
# בחלונית הקוד למטה מופיעים מימושים לפונקציות max2 ו-max3 אותן כבר פגשנו.
# בנוסף, מופיע מימוש לפונקציה בשם max4_v1 - הפונקציה מקבלת כקלט 4 מספרים - a,b,c,d, ומחזירה את הגדול מביניהם.
# הפונקציה עושה שימוש בפונקציות max2 ו-max3 לפי דיאגרמת הבלוקים הבאה:

# %% [markdown]
# <img width=400 height=400 src='data:image/png;base64,...' />

# %% [markdown]
# עליכם לממש את הפונקציה max4_v2 שחתימתה מופיעה בחלונית הקוד. גם פונקציה זו מקבלת כקלט 4 מספרים ומחזירה את הגדול מביניהם, אלא שכאן עליכם לממש אותה לפי דיאגרמת הבלוקים הבאה:

# %% [markdown]
# <img width=400 height=400 src='data:image/png;base64,...' />

# %% [markdown]
# **דרישות מימוש** - במימוש של הפונקציה max4_v2 אסור להשתמש בפונקציה max3 וחייבים להשתמש בפונקציה max2.
# לאחר שסיימתם את כתיבת הקוד, הריצו אותו ובדקו בחלונית הפלט האם המימוש עובד.
#
#
# - כזכור, בחלונית הקודבורד הבאה מופיעה המילה `pass`. שימו לב כי עליכם **להחליף** את pass בקוד שלכם בשביל להשלים את התרגיל.
# - אחרי בדיקות הנכונות של הקוד שלכם, אחרי ההערה ### EXTRA TESTS ###, מופיעות הפעם גם בדיקות שעמדתם בדרישות למימוש הפתרון שצוינו לעיל. אינכם אמורים להבין חלק זה או לשנות אותו, אבל תוכלו לראות את תוצאות הבדיקות האלו בחלונית הפלט.

# %%
def max2(a,b):
    if a > b:
        return a
    else:
        return b

def max3(a,b,c):
    max_a_b = max2(a,b)
    max_all = max2(max_a_b, c)
    return max_all
    
def max4_v1(a,b,c,d):
    max_a_b_c = max3(a,b,c)
    max_all = max2(max_a_b_c, d)
    return max_all
    
def max4_v2(a,b,c,d):
    # delete pass and fill in your code below
    pass




### TESTS ###

print("********************")
print("Starting the test:")

print("********************")
print("Checking the maximum between 3, 7, 12, -20")
ans = max4_v2(3, 7, 12, -20)
if ans == 12:
    print("CORRECT: Very good, 12 is the maximal number")
else:
    print("WRONG: 12 is the maximal number but the code returned", ans)

print("********************")
print("Checking the maximum between -10, -20, -25, -12")
ans = max4_v2(-10, -20, -25, -12)
if ans == -10:
    print("CORRECT: Very good, -10 is the maximal number")
else:
    print("WRONG: -10 is the maximal number but the code returned", ans)
# Out:
# ********************
# Starting the test:
# ********************
# Checking the maximum between 3, 7, 12, -20
# WRONG: 12 is the maximal number but the code returned None
# ********************
# Checking the maximum between -10, -20, -25, -12
# WRONG: -10 is the maximal number but the code returned None

# %% [markdown]
# ### הרחבה: מודולריות קוד

# %% [markdown]
# ביחידה הקודמת ראינו שני מימושים שונים לפונקציות אשר מוצאות ערך מקסימלי מתוך עשרה ערכים שונים. להלן תזכורת למבנה של שני המימושים הללו:

# %% [markdown]
# <img width=800 height=400 src='data:image/png;base64,...' />

# %% [markdown]
# בשני המימושים השתמשנו ב"אבני בניין" בסיסיות על מנת לממש את הפונקציה max10. כלומר, השתמשנו בפונקציות אשר מוצאות ערך מקסימלי מבין 2, 3 ו-5 איברים, והרכבנו אותן כך שבסופו של דבר מצאנו באמצעותן את הערך המקסימלי מבין עשרת הערכים שבקלט.
#
# התהליך שבו אנחנו מבצעים **שינויים בתוכנה שלנו באמצעות החלפה של רכיבים ספציפיים לפי הצרכים שלנו** מביא לידי ביטוי את תפיסת **המודולריות (Modularity)** שבכתיבת קוד. לפי תפיסה זו אנחנו יכולים לחשוב על הקוד אותו אנחנו כותבים כמורכב מרכיבי תוכנה נפרדים (באנגלית, Module, ומשם מגיע המונח) איתם אנחנו יכולים לשחק על מנת לממש תוכנות שונות. במקרה שלנו הרכיבים היו הפונקציות max2, max3, max5 ובאמצעות הרכבה שלהן בדרכים שונות מימשנו את הפונקציה max10.
#
# נשמע מוכר? אנו נתקלים במודולריות במקרים רבים ביום-יום, ודוגמא מצוינת לכך היא כשאנחנו מרכיבים ארון שקנינו בחנות רהיטים. הארון שלנו מורכב, בין השאר, מהרכיבים הבאים:
#
# 1. דלת הארון, אשר יכולה להיות מעץ מלא או מזכוכית
# 2. תוכן הארון, אשר יכול להיות מחולק למדפים או לתא לתלייה של בגדים
# 3. רגלי הארון, אשר יכולות להיות בעלות תושבת קבועה או בעלות גלגלים
#
# מאחר שכל רכיב אינו תלוי ברכיבים האחרים, אנחנו יכולים לשחק עם קומבינציות שונות, למשל – ארון עם דלת זכוכית, מדפים וגלגלים או ארון עם דלת עץ, מדפים ורגלים קבועות.

# %% [markdown]
# נשים לב כי **על מנת לתמוך במודולריות הזאת, החלקים המקשרים בין הרכיבים צריכים להיות תואמים**. לדוגמא, אם הצירים אשר מחברים בין גוף הארון והדלת בעלי חורים לשני ברגים, עלינו לוודא כי גם בדלת הזכוכית וגם בדלת העץ ישנם חורים לשני ברגים, אחרת לא נוכל לחבר אותן לארון. בדיוק באותו אופן בשני המימושים לפונקציה max10 דאגנו להתאים בין הרכיבים הבסיסיים שלנו והאופן בו הם משתלבים במערכת. לפונקציית max5 נכנסים תמיד חמישה ערכים ואילו לפונקציית max3 נכנסים תמיד שלושה.
#
# לבסוף, כשבידינו המימוש לפונקציה max10, קיבלנו למעשה אבן בניין נוספת לארגז הכלים שלנו. כעת, אם נדרש לבנות למשל פונקציה המוצאת את המקסימום מבין 20 ערכים, נוכל להשתמש בפונקציה max10 כמודול בתוך הפונקציה החדשה שלנו. כלומר, **בתכנות מודולרי אנחנו חושבים על הקוד שלנו לא כעל רצף ארוך של פקודות בודדות ובלתי תלויות, אלא כעל אוסף של רכיבים בסיסיים, אותם אנחנו יכולים לשלב בדרכים שונות כדי לממש מערכות מורכבות**.

# %% [markdown]
# ## פרמטרים לפונקציות עם ערכי ברירת מחדל

# %% [markdown]
# - ניתן לציין ערכי ברירת מחדל עבור הארגומנטים של הפונקציה
# - ערך ברירת המחדל ישמש רק כאשר הפונקציה תיקרא מבלי לציין ערך לארגומנט
# - ערכים עם ברירת מחדל תמיד מופיעים **אחרי** ערכים בלי ברירת מחדל.

# %%
def f1(x, y=1):
    return x+y

# %%
f1(1, 2)

# %%
f1(3)

# %%
f1()

# %% [markdown]
# #### דוגמאות נוספות

# %%
def f2(x=1, y=2, z=3):
    return x+y+z

# %%
f2()

# %%
f2(10)

# %%
f2(y=5)   # in this call: x = 1, y = 5, z = 3

# %%
def f2(x=1, y, z):   # Invalid syntax
    return x+y+z

# %% [markdown]
# ### פונקציה כפרמטר

# %%
def add(x, y):
    return x + y

def calculator(a,b,op):
    return op(a,b)

print(calculator(2, 3, add))

# %% [markdown]
# ## פונקציות אנונימיות (lambda)

# %% [markdown]
# - Shorter syntax for function
# - Suitable for short function
# - mostly used for a one-time inline function

# %% [markdown]
# ### דוגמא: מחשבון

# %%
add = lambda x, y: x+y
add(1,2)

# %%
substract = lambda x, y:  x-y
substract(1,2)

# %%
def calculator(a,b,op):
    return op(a,b)

# %%
print(calculator(13,7,add))

print(calculator(13,7,substract))

# %% [markdown]
# # `tuple` – רשימה קבועה

# %% [markdown]
# - `tuple` היא מבנה נתונים הדומה ל־`list`, אך הוא בלתי־ניתן לשינוי (immutable).

# %%
t = ("don't", "worry", "be", "happy") # definition

# %%
 t[0] # indexing

# %%
t[-1] # backwords indexing

# %%
t[1:3] 	# slicing

# %%
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
my_tuple[0:2]

# %%
my_tuple[1] = 10

# %% [markdown]
# <span style='color:red'> אין אפשרות לקרוא לשום מתודה שראינו בlist שמשנה את הערך המקורי כמו append, remove וכו' </span>

# %% [markdown]
# # מילונים: `dict`

# %% [markdown]
# - מבנה נתונים אסוציאטיבי
#     - התאמה בין מפתח לערך (Key – Value)
#     - גישה לערכים לפי מפתח (ולא לפי מיקום כמו ברשימות)
#     - אין הבטחה לסדר של האיברים
#     - מהיר מאוד!
#
# - אינטואיציה - דפי זהב:
#     - אם יש לך שם, קל למצוא את מספר הטלפון המתאים
#     - אם יש לך מספר טלפון, קשה להתאים לו שם
#
#
# - המפתחות צריכים להיות:
#     - ייחודיים
#     - בלתי ניתנים לשינוי (immutable)
#
# תחביר:
# ```python
# {key1:val1, key2:val2,…}
# ```

# %% [markdown]
# <img width=600 heigth=200 src="data:image/png;base64,..." />

# %% [markdown]
# ### דוגמא

# %%
phonebook = {'Eric Cartman': '2021', 'Stan March': '5711', 'Kyle Broflovski': '2781'}
print(phonebook)

# %% [markdown]
# - הערה: באופן כללי, זוגות המפתח-ערך במילון לא בהכרח יוצגו באותו סדר שבו הוגדרו.
#   מילונים לא מבטיחים סדר מסוים של מפתחות.
# - החל מ-Python 3.7, הסדר של המילון מובטח להיות לפי סדר ההכנסה,
#   אך לא מומלץ להסתמך על כך משום שזה תלוי בגרסה/שפה.

# %% [markdown]
# - גישה לפי מפתח:

# %%
phonebook['Eric Cartman']

# %% [markdown]
# - בדיקה אם מפתח קיים:

# %%
'Kenny McCormick' in phonebook

# %% [markdown]
# - הוספה:

# %%
phonebook['Kenny McCormick'] = '1234'
print(phonebook)

# %% [markdown]
# מה קורה כאשר מוסיפים מפתח שכבר קיים?

# %%
print(phonebook)
phonebook['Kenny McCormick'] = '2222'
print(phonebook)

# %% [markdown]
# איך נוכל להוסיף עוד כניסה עבור Kenny McCormick בפנקס הטלפונים?

# %% [markdown]
# רעיון: להוסיף כתובת למפתח

# %%
phonebook= {['Kenny McCormick', 'Southpark']: '2222'}

# %% [markdown]
# מה הבעיה?

# %% [markdown]
# - <span style='color:red'> מפתחות חייבים להיות בלתי ניתנים לשינוי (immutable)! </span>
# - מה אפשר לעשות?

# %% [markdown]
# תיקון: השתמשו ב־tuples בתור מפתחות!

# %%
phonebook= {('Kenny McCormick', 'Southpark'): '2222'}
print(phonebook)

# %% [markdown]
# ### Dictionary methods

# %% [markdown]
# | פונקציה            | תיאור                                                                 |
# |---------------------|------------------------------------------------------------------------|
# | `D = {}`            | יוצר מילון ריק                                                         |
# | `D[k] = value`      | קובע את הערך של `D[k]`                                                 |
# | `k in D`            | מחזיר `True` אם `k` הוא מפתח במילון, אחרת `False`                    |
# | `D[k]`              | מחזיר את הערך של המפתח `k` (יזרוק KeyError אם `k` לא קיים)           |
# | `D.get(k, [d])`     | מחזיר את `D[k]` אם קיים, אחרת את `d` (ברירת מחדל: `None`)             |
# | `D.keys()`          | מחזיר תצוגה של כל המפתחות במילון                                     |
# | `D.values()`        | מחזיר תצוגה של כל הערכים במילון                                      |
# | `D.items()`         | מחזיר תצוגה של זוגות `(מפתח, ערך)` כ־tuples                          |
# | `D.pop(k, [d])`     | מסיר את המפתח `k` ומחזיר את ערכו; אם לא נמצא מחזיר `d` או שגיאה       |
# | `D.copy()`          | יוצר העתק רדוד של המילון (המילון בלבד מועתק, לא האובייקטים שבתוכו)   |
# | `D.update(other)`   | מוסיף את כל הפריטים מהמילון `other` לתוך `D`                         |

# %% [markdown]
# - ארגומנט שמסומן כ־<span style="color:red"><i>[d]</i></span> הוא אופציונלי
#     - אם לא מציינים אותו, ייעשה שימוש בערך ברירת המחדל
# - מידע נוסף על מתודות של מילון נמצא [כאן](https://docs.python.org/3/library/stdtypes.html#dict)

# %% [markdown]
# ### תצוגות מילון (Dictionary Views)
#
# - המתודות של מילון `keys()`, `values()`, `items()` מחזירות תצוגה איטרבילית דינמית.
# - החל מ-Python 3.7, סדר התצוגה של המילון נשמר לפי סדר ההכנסה, אבל לא כדאי להסתמך על כך.
# - ניתן לאחזר תצוגה בלולאה, לבדוק שייכות עם `in`, והיא משתנה דינמית כאשר המילון משתנה.
# - התצוגה משתנה כאשר המילון משתנה
#     - <span style='color:red'>לא לשנות את המילון תוך כדי איטרציה על אחת מהתצוגות שלו</span>

# %%
d={'A':65, 'B':66, 'C':67}
print(d)
print(d.keys())
print(d.values())
print(d.items())
a=list(d.items())

# %%
a=d.keys()
print(a)
d['D']=68
d['E']=69
print(a)
print('E' in a)

# %% [markdown]
# ## דוגמה: מונה תדירות תווים
#
# - מטרה: לספור את התדירות של כל אות במחרוזת

# %%
def get_char_count(text):
    char_count = {}
    for char in text:
        if not char in char_count:
            char_count[char] = 1
        else: 
            char_count[char] += 1
    return char_count

# %%
text = 'jerry'
get_char_count(text)

# %%
text = 'supercalifragilisticexpialidocious'
get_char_count(text)

# %% [markdown]
# ### מונה תדירות תווים משופר
#
# - שימוש ב-`get()`:

# %%
def get_char_count(text):
    char_count={}
    for char in text:
        char_count[char] = char_count.get(char, 0) + 1
    return char_count

text = 'jerry'
get_char_count(text)

# %% [markdown]
# ### מונה תדירות תווים: הדפסת תוצאה ממוינת

# %% [markdown]
# באיזה סדר נדפיס את התווים?

# %% [markdown]
# **אפשרות ראשונה - לפי סדר אלפביתי**: תחילה את מספר המופעים של a, לאחר מכן את מספר המופעים של b וכו'

# %%
def print_by_keys_order(d):
    sorted_chars = sorted(d)
    for char in sorted_chars:  
        print(char, ':', d[char])

text = 'supercalifragilisticexpialidocious'
cc = get_char_count(text)
print_by_keys_order(cc)

# %% [markdown]
# - **אפשרות שניה - לפי תדירות:** להתחיל מהאות שמופיעה הכי הרבה פעמים ולסיים בזו שמופיעה הכי מעט

# %%
def print_by_keys_order(d):
    sorted_chars = sorted(d, key=d.get, reverse=True)
    for char in sorted_chars: 
        print(char, ':', d[char])

text = 'supercalifragilisticexpialidocious'
cc = get_char_count(text)
print_by_keys_order(cc)

# %% [markdown]
# ### יצירת רשימות בשורה אחת: List Comprehension

# %% [markdown]
# - דרך פייתונית ליצירת רשימות.
# - שילוב של רשימות ולולאות for.
# - תחביר:
#     - `[expression for item in list]`
# - אפשר גם לכתוב:
#     - `[expression for item in list if condition]`

# %% [markdown]
# ### יצירת רשימות בשורה אחת: דוגמא

# %% [markdown]
# במקום

# %%
my_list = []
for i in range(10):
    my_list.append(i*i)
my_list

# %% [markdown]
# ניתן לכתוב כך:

# %%
[i**2 for i in range(10)]

# %% [markdown]
# ### דוגמאות נוספות

# %%
l = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
[word.upper() for word in l]

# %%
[word for word in l if len(word) < 4]

# %%
[i ** 2 if i % 3 == 0 else i ** 3 for i in range(2, 13) if i % 6 != 0]
