# %%
# %%html
# <style>
# table {display: inline-block}
# </style>

# %% [markdown]
# # מבוא
#
# ## Python Programming for Engineers
# ### Tel-Aviv University / 0509-1820 / Spring 2025

# %% [markdown]
# ### Course Objectives
#
# - Develop basic **programming** and **algorithmic** skills
#     - not how computer hardware works

# %% [markdown]
# ### Syllabus:
# - Python programming basics
# - Recursion
# - Object-Oriented Programming
# - Scientific Calculations (Numpy)
# - Image processing (Numpy)
# - Data analysis (Pandas)
# - Data visualization (Pandas)

# %% [markdown]
# ### Preface
# - We assume no prior knowledge
# - However, we advance fast
# - The only way to keep on track is to practice!
#
# <img width=400 height=400 src='data:image/png;base64,...'>

# %% [markdown]
# #### Course website: [http://courses.cs.tau.ac.il/pyProg/2425b/](http://courses.cs.tau.ac.il/pyProg/2425b/)
# - Administration
# - Course schedule
# - Presentations
# - Jupyter Notebooks
# - Installation guides
# - External resources
# - Homework
#
# #### Moodle: [https://moodle.tau.ac.il/course/view.php?id=50918202098](https://moodle.tau.ac.il/course/view.php?id=50918202098)
# - Homework submissions
# - Forums (general + assignment specific)
#
# #### There's also Moodle for each recitation (TA announcements etc.)

# %% [markdown]
# ### Recitation
#
# - Practical sessions
# - In a standard classroom
# - Purposes:
# - Jupyter Notebooks
#      - Practice topics presented in class
#          - Hand-on experience in practical tools
#          - Pycharm
#      - Background for homework assignments

# %% [markdown]
# ### Homework
# - Guidelines under Exercises tab in course website.
# - A lot of hands-on experience
# - **No other way to learn how to program**
#
#
# #### Where can I work?
# - Computer labs
# - Time and location appear in the course website
#     - **Back-up with email / disk-on-key/ dropbox / etc. !**

# %% [markdown]
# ### Submission Guidelines
#
# - Submission in **singles!**
# - 7 exercises
# - Must submit at least 6 exercises
# - Average of best 6 exercises is 25% of the final grade
# - 10 grace days

# %% [markdown]
# ### Guided Lab
# - Optional practical session in a computer lab
# - Technical support (Pycharm, Jupyter Notebooks, etc.)
# - **Use it**

# %% [markdown]
# ### The exam
# - Final grade is composed out of homework and final exam
# - You must pass the exam to pass the course
# - Written exam
# - Includes all course material:
#     - Lectures, recitations, and HW

# %% [markdown]
# ### Today's agenda
# - Brief background to programming
# - Python basics:
#     - Variables (`int`, `float`, `string`, `boolean`)
#     - Operators (arithmetic, comparison, logical)
#
# - Functions
# - Conditional statements (`if`)

# %% [markdown]
# ### Programming Languages Basics
# - A computer program is a sequence of text instructions that can be “understood" by a computer and executed.
# - A programming language is a machine-readable artificial language designed to express computations that can be performed by a computer.
# - Over 500 different computer languages are listed in Wikipedia
#
# <img width=200 height=200 src="data:image/png;base64,..." />

# %% [markdown]
# ### Machine Code (Language)
#
# Computers understand only machine language.
# - Basically, looks like a sequence of 1’s and 0’s.
#     - Very inconvenient to work with and non-intuitive.
#     - Computer languages were created for human     convenience.
# - The computer does not understand C/Python/Java - They must be “translated” into machine language
#     - In this course, we do not care how the computer does that

# %% [markdown]
# ### Computer program
# - A sequence of instructions designed to achieve a specific purpose
# - The instructions are executed sequentially. No instruction is executed before the previous is completed
#
#
# <img width=400 height=400 src="data:image/png;base64,...">

# %% [markdown]
# ### Python
# - Since 1991
# - Easy to learn
# - Short development time
# - Fast enough for most applications
# - Huge community
# - Widely used in the industry
# - Machine Learning
#
# <img width=400 height=200 src="data:image/png;base64,..." />

# %% [markdown]
# ### Installing and running Python
# - Install Anaconda
# - Install Pycharm **Community** edition
#     - Use only **Python 3.11.x**
# - Guides are provided in the course website (Kickstart guide, installation manuals, etc.)
#
# Let’s see together how Pycharm looks like…
# Using variables to store data in memory

# %% [markdown]
# ### Using variables to store data in memory
# - Computer programs manipulate data.
# - Data is given either as input or calculated by the program.
# - To access it later, data must be remembered.
# - Therefore, computer programs use variables to  store data in the memory.
# - Each variable has…
#     - A value (content, the stored data)
#     - A name (a shortcut to its address in memory)
#     - A type (str, int, float, bool)

# %% [markdown]
# ### Program variables
# - Each variable has: Name, Value, Type (and an Address of the location in memory where its value is stored).
# - In Python we create variables simply by assigning a value to a variable name:
#
# ```python
# s = "Bob"
# r = True
# age = 35
# ```
# <img width=300 height=150 src="data:image/png;base64,..." />
#
# The variable’s type is automatically determined in Python based on its assigned values and actions

# %% [markdown]
# ### Data types in Python
# - Commonly used built in data types:
#     - Numeric types: int, float
#     - Boolean: bool
#     - String: str
# - Why do we need different types?
#     - Saves memory
#     - Execution speed
#     - Types have different actions

# %% [markdown]
# ### Data types in Python: illustration
# ```python
# n=17
# pi=3.14159
# message="whats'up Doc?"
# b=True
# ```
# <img width=400 height=600 src="data:image/png;base64,..." />

# %% [markdown]
# ### Data Types: execution example

# %%
a=5
print(a)

# %%
a = 'Hello'
print(a)

# %%
print('Hello' + str(6))

# %% [markdown]
# ### The `type` command returns the type of a variable/expression

# %%
print(type(4))

# %%
print(type(3.14159))

# %% [markdown]
# ### Variables and Assignments
# - Left-hand side is a variable name.
# - Right-hand side is an expression
# ```python
# n = 10
# m = (10 + 4) * 5
# ```
# <img width=180 height=50 src="data:image/png;base64,..." />
# - Variable's name - a sequence of letters and digits,
# 	starting with a letter.
#
# The **interpreter**:
# - Evaluates the expression
# - Assigns its value to the variable.

# %% [markdown]
# ### Variables and assignments: an example

# %% [markdown]
# Changing the value of a variable:

# %%
n=10
print(n)

# %%
n=11
print(n)

# %% [markdown]
# Changing the type of a variable:

# %%
print(type(n))
n = 1.3141
print(type(n))

# %% [markdown]
# Variables can be used in expressions:

# %%
pi = 3.14159
print(pi * 2 + 1)

# %% [markdown]
# Referring to undefined variables leads to runtime error

# %%
check_this

# %% [markdown]
# ### Arithmetic operations

# %% [markdown]
# <img width=800 height=800 src='data:image/png;base64,...'>

# %% [markdown]
# #### What’s the type of `8/5` ?  And of `8//5` ?

# %% [markdown]
# ### Playing with variables

# %%
a=3
print(a)
b=5
print(b)
c = a + b
print(c)
c = c * 2
print(c)
print(b**a)
print(b/a)
print(b//a)
print(b%a)

# %% [markdown]
# ### Strings
# - String variables are used to save text.
# - An ordered sequence of characters.

# %%
s = "Hello"
print(s)

# %%
print(s[0])
print(s[-1])

# %% [markdown]
# ### Strings Indices

# %% [markdown]
# <img width=300 height=200 src='data:image/png;base64,...'>

# %%
a = 'Hello'

# %%
print(str.find(a, 'H'))
print(a.find('H'))

# %%
print(a[0])
print(a[1])
print(a[-1])
print(a[4])

# %%
print(a[5])

# %% [markdown]
# ### String access

# %% [markdown]
# <img width=300 height=200 src='data:image/png;base64,...'>

# %%
a = 'Hello'

# %%
print(a[1])
print(a[1:3])
print(a[1:])

# %%
print(a[-4:-2])
print(a[:-3])
print(a[-3:])

# %% [markdown]
# ### Strings are a sequence of characters
# - Every character in a string is mapped to a specific number based on the famous ASCII table.
# - Strings are saved in memory as a sequence of numbers in binary form.
# - In python:
#     - `\n` represents new line
#     - `\t` represents tab

# %% [markdown]
# ### ASCII table

# %% [markdown]
# <img width=600 height=600 src='data:image/png;base64,...'>

# %% [markdown]
# ### String type

# %%
a = 'Hello'

# %%
print(len(a))

# %%
print(a + "world")

# %%
print(str.lower(a))

# %%
print(b)

# %% [markdown]
# ### String concatenation

# %%
s1 = "He"
s2 = "llo"
s3 = s1 + s2
print(s3)

# %%
s4 = s3 + " World"
c = "!"
print(s4+" "+str(2022)+" "+c)

# %%
print(s4, 2022, c)  # automatically adds spaces in between

# %% [markdown]
# ### Strings are immutable
# - You cannot mutate (change) existing strings. Only create new ones!

# %%
a = "abc"
a[0] = "d"

# %% [markdown]
# However, pointing to another string is valid:

# %%
a="abc"
print(a)
a="gggg"
print(a)

# %% [markdown]
# ### Strings are immutable
# - Immutable variables cannot be changed after created.
# - Applying operations on immutable variables usually return a **new variable** rather changing the original variable

# %%
a = "hello"
b = a.title()
print("a value is:", a)
print("b value is:", b)

# %% [markdown]
# ### String operators

# %% [markdown]
# <img width=800 height=800 src="data:image/png;base64,...">

# %% [markdown]
# ## Strings functions (methods)
# - The `str` type in Python includes many built-in commands for working with Strings

# %%
print(str.upper('Assaf'))
print(str.upper('Assaf'))
print(str.lower('Noga'))
print(str.replace('Python class occurs on Mondays', 'Mondays', 'Tuesdays'))
print('Py' + 'thon')
print(str.title('python course for engineers'))
print(str.title(str.replace('Python class occurs on Mondays', 'Mondays', 'Tuesdays')))
print('repeat' * 4)

# %% [markdown]
# ### Other functions of String
#
# - **`len`**
# - `find`, `startswith`, `endswith`
# - `isalpha`, `isdigit`, `islower`
# - `join`, `replace`
# - `strip`, `rstrip`
# - `split`
#
# **<span style="color:red">These function are very important! Mandatory for solving many problems.</span>**
#
# More About Strings: http://www.tutorialspoint.com/python/python_strings.htm
#
# Google it...

# %% [markdown]
# ### Type conversion
# - Convert variable type using int(), str() and float()

# %%
num = 123
print(num, type(num))
num_str = str(num)
print(num, type(num))
num_float = float(num)
print(num_float, type(num_float))

# %% [markdown]
# ### Comparison Operators
# - Compares two variables and returns a Boolean type value (True/False)

# %% [markdown]
# <img width=800 height=800 src='data:image/png;base64,...'>

# %% [markdown]
# ### Comparison operators: examples

# %%
print(5==5.0)

# %%
print(6!=2*3)

# %%
print(-2>=1)

# %%
print(3<=3)

# %%
x=3<3
print(x, type(x))

# %%
print('a'!='b')

# %% [markdown]
# ### Logical Operators
# - Operate on two Booleans and return Booleans

# %% [markdown]
# <img width=800 height=600, src="data:image/png;base64,...">

# %%
a = True
b = True 
c = False
d = False

# %%
print(a and b)

# %%
print(a and c)

# %%
print(a or c)

# %%
print(not a)

# %% [markdown]
# ## Function

# %% [markdown]
# ### How to Calculate the circumference of three rectangles?
#
# <img width=800 height=600 src="data:image/png;base64,...">

# %%
c1=3*2+3*2
print(c1)
c2=1*2+3*2
print(c2)
c3=3*2+5*2
print(c3)

# %% [markdown]
# ### <span style="color:red">Code Duplication</span>

# %% [markdown]
# #### Code duplication is bad
#
# - Duplicated bugs (harder to fix later)
# - Longer programs
# - Copy & Paste errors
#
# Rule of Thumb - Write the code once!
# - Use it several times with different arguments (Code reuse is encouraged)

# %% [markdown]
# ### Function – Definition
# - A **named** sequence of statements that performs a **specific** task independently of the remaining code.
#
# <img width=300 height=200 src="data:image/png;base64,...">

# %% [markdown]
# ### Why functions?
# - Modularity - Break a task into smaller sub-tasks (divide and conquer), enables code reuse
# - Abstraction – Solve each problem once and wrap it in a function
# - Maintenance - Solve bugs once
# - Readability – Main code is shorter, implementation details are hidden within functions
# - Limited Variable Scope - Temporary variables are restricted to the function’s scope

# %% [markdown]
# ### Built-in Functions
# - We already used some built-in functions:

# %%
type(5)

# %%
len("abcde")

# %% [markdown]
# Other built-in functions can be found [here](http://docs.python.org/library/functions.html)

# %% [markdown]
# ### Defining a new function in Python

# %% [markdown]
# #### Writing a function

# %% [markdown]
# ```python
# def function_name(parameter1, parameter2,...):
#     statement1
#     statement2
#     statement3
#     ...
#     return result1, result2, ...
# ```
# -  <span style="color:red">Note the indentation!
# - `return` is optional
#     - if return is not specified, the function returns the constant None

# %% [markdown]
# #### Calling a function
# ```python
# var1, var2,… = function_name(val1, val2,...)
# ```

# %% [markdown]
# ### Back to our example: calculate circumference of rectangles

# %% [markdown]
# <img width=600 height=600 src="data:image/png;base64,...">

# %% [markdown]
# ### Defining the function

# %%
def circumference(x,y):
    return 2*x +2*y

# %% [markdown]
# ### Using/calling the function

# %%
a = circumference(4,6)
print(a)

# %%
print(circumference(2,3))

# %% [markdown]
# ### Function’s Input / Output
# - Input: Arguments
#     - Can be of any type - int / float / str / bool
#
# - Output: The return statement
#     - Returns a value (of any type) to the function caller.
#         - Multiple values are wrapped in tuple
#     - no return or no value after return - returns None
#
# - #### `return` immediately stops the function’s execution and returns to the caller
# - #### <span style='color:red'> `return` is different from print</span>

# %%
def print_lyrics():
    print("The wheels on the bus go round and round")
    print("Round and round, round and round")
def repeat_lyrics(): 
    print_lyrics() 
    print_lyrics()
    
repeat_lyrics()

# %% [markdown]
# Check it on [Python Tutor](https://pythontutor.com/render.html#code=def%20print_lyrics%28%29%3A%0A%20%20%20%20print%28%22The%20wheels%20on%20the%20bus%20go%20round%20and%20round%22%29%0A%20%20%20%20print%28%22Round%20and%20round,%20round%20and%20round%22%29%0Adef%20repeat_lyrics%28%29%3A%20%0A%20%20%20%20print_lyrics%28%29%20%0A%20%20%20%20print_lyrics%28%29%0A%20%20%20%20%0Arepeat_lyrics%28%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# ### Conditional statements (`if`)

# %% [markdown]
# Syntax:
# ```python
# if condition:
#     statement1
#     statement2
# ```

# %% [markdown]
# if condition is True, statements are executed

# %% [markdown]
# <img width=800 height=800 src="data:image/png;base64,...">

# %% [markdown]
# ### `if` examples

# %%
def divisible(num):
    if num % 18 == 0:
        print(num, "is divisible by 18")
    print("Goodbye")

# %%
divisible(53)

# %% [markdown]
# ### Indentation in conditional statements
# - Following the if statement: one tab to the right opens a new block (scope).
# - Indicates the following statements are within the scope of this if.

# %% [markdown]
# ### `if-else`
# ```python
# if  condition1:
#     statement1
# else:
#     statement2
#
# rest of code
# ```
# - if condition1 is true $\rightarrow$ execute statement1
# - if condition1 is false $\rightarrow$ execute statement2
# - execute rest of code
#
# Indentation:
# - `else` is not a part of the `if` scope
# - The statements under else are indented

# %% [markdown]
# ### `if`-`else` workflow

# %% [markdown]
# <img width=600 height=500 src="data:image/png;base64,..." />

# %% [markdown]
# ### `if`-`else` example

# %%
def is_square(width, height):
    if width == height:
        print("found a square")
    else:
        print("found a rectangle")
    print("done")

# %%
is_square(4,4)

# %% [markdown]
# ### `if`-`elif`-`else`
#
# #### elif = else-if
#
#
# ```python
# if condition1:
#     statement1
# elif condition2:
#     statement2
# else:
#     statement3
# rest of code
# ```
# - condition1 is true $\rightarrow$ execute statement1
# - condition1 false and condition2 true $\rightarrow$ execute statement2
# - condition1 and condition2 are false $\rightarrow$ execute statement3
# - execute rest of code

# %%
def which_triangle(a,b,c):
    if a == b and b == c:
        x="Equilateral triangle"
    elif a==b or a==c or b==c:
        x="Isosceles triangle"
    else:
        x="another kind of triangle"
    return x

# %%
result=which_triangle(4,4,4)
print(result)

# %% [markdown]
# ## That's all for now... 😯
